# %% [markdown]
# <a href="https://colab.research.google.com/github/krrish9669/machine-learning-new/blob/main/1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("unsdsn/world-happiness")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/world-happiness

# %%
import os
os.listdir( "/kaggle/input/world-happiness")
# Out:
# ['2015.csv', '2017.csv', '2019.csv', '2018.csv', '2016.csv']

# %%
df1 = pd.read_csv("/kaggle/input/world-happiness/2019.csv")

# %%
df2=df1["Score"]
df3=df1["GDP per capita"]

# %%
print(df1.columns)
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
x=np.c_[df3]
y=np.c_[df2]

# %%
df1.plot(kind="scatter",x="GDP per capita",y="Score")
plt.show()

# %%
lin_reg_model=sklearn.linear_model.LinearRegression()
lin_reg_model.fit(x,y)
# Out:
# LinearRegression()

# %%
Kn=sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)
Kn.fit(x,y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
from re import X
X_new=[[1.33]]
print(lin_reg_model.predict(X_new))
print(Kn.predict(X_new))
# Out:
# [[6.34948202]]
# [[6.51066667]]
